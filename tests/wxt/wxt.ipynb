# %%
from heapy.data.retrieve import epRetrieve
from heapy.data.xselect import epXselect

# %%
wxt_rtv = epRetrieve.from_wxtobs('ep13600003859wxtCMOS44l23v2', 's2')
wxt_rtv.rtv_res
# Out:
# {'satelite': 'WXT',
#  'obsname': 'ep13600003859wxtCMOS44l23v2',
#  'srcid': 's2',
#  'evt': '/Users/jyang/Documents/EinsteinProbe/WXT/ep13600003859wxtCMOS44l23v2/ep13600003859wxt44po_cl.evt',
#  'rmf': '/Users/jyang/Documents/EinsteinProbe/WXT/ep13600003859wxtCMOS44l23v2/ep13600003859wxt44.rmf',
#  'arf': '/Users/jyang/Documents/EinsteinProbe/WXT/ep13600003859wxtCMOS44l23v2/ep13600003859wxt44s2.arf',
#  'armreg': '/Users/jyang/Documents/EinsteinProbe/WXT/ep13600003859wxtCMOS44l23v2/ep13600003859wxt44arm.reg',
#  'reg': '/Users/jyang/Documents/EinsteinProbe/WXT/ep13600003859wxtCMOS44l23v2/ep13600003859wxt44s2.reg',
#  'bkreg': '/Users/jyang/Documents/EinsteinProbe/WXT/ep13600003859wxtCMOS44l23v2/ep13600003859wxt44s2bk.reg'}

# %%
wxt_event = epXselect.from_wxtobs('ep13600003859wxtCMOS44l23v2', 's2')

# %%
wxt_event.timezero = '2024-02-19T06:21:42'
wxt_event.lc_t1t2 = [-200, 300]
wxt_event.lc_binsize = 2

# %%
wxt_event.extract_curve(savepath='./curve', show=True)

# %%
wxt_event.calculate_txx(xx=0.9, savepath='./curve/t90')
# Out:
# +------------------------------------------------+
#  id#  Txx       Txx-    Txx+    Txx1    Txx2
# +-----------------------------------------------+
#  1    134.083   6.480   4.985   11.845  145.928
# +------------------------------------------------+

# %%
wxt_event.extract_spectrum(spec_slices=[[0, 70], [0, 160]], savepath='./spectrum')
